# %% [markdown]
# <a href="https://colab.research.google.com/github/GSinseswa721/myflask/blob/main/EasyNMT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U easynmt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.5 MB 6.9 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 62.2 MB/s
# ...
#      |████████████████████████████████| 68 kB 4.9 MB/s
# ...
#      |████████████████████████████████| 163 kB 58.8 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 49.9 MB/s
# ...
#   Using cached pybind11-2.10.1-py3-none-any.whl (216 kB)
# ...
#   Created wheel for easynmt: filename=EasyNMT-2.0.2-py3-none-any.whl size=19919 sha256=f721631c06e70cf8f20fdd2a8bc0a15acdffe91a793fde33be8fdb135ef970ed
#   Stored in directory: /root/.cache/pip/wheels/d1/57/06/53ca38645e14d4537a41e5a36da2026e10f54ae88240dd5190
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp37-cp37m-linux_x86_64.whl size=3163266 sha256=636c91f09e54193494f3f65f5a6553b9f606847ea0664895212b0df0982645ae
#   Stored in directory: /root/.cache/pip/wheels/4e/ca/bf/b020d2be95f7641801a6597a29c8f4f19e38f9c02a345bab9b
# ...

# %%
from easynmt import EasyNMT

# %%
model = EasyNMT('opus-mt')
# Out:
# 11.9kB [00:00, 13.4MB/s]

# %%
sentences = [
    'Jesus is alive!',
    'Hands on projects is our priority',
    "I don't have anything",
    'It is a rainly day',
    "'It is what it is':Legend Belise once said."

]

# %%
translations = model.translate(sentences, target_lang='fr')
translations = model.translate(sentences, target_lang='rw')
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1364: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 512 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,

# %%
translations
# Out:
# ['Yesu ni muzima!',
#  'Ibintu tugomba gushyira mu mwanya wa mbere ni byo dushyira mu mwanya wa mbere',
#  '........',
#  "Ni umunsi w'imvura",
#  'Icyo ni cyo Choeegedese yigeze kuvuga.']

# %%
import json

# %%
with open('/content/lang.json','r+') as file_lang:
  content = file_lang.read()

# %%
language_json = json.loads(content)

# %%
language_json[1]
# Out:
# {'code': 'aa', 'name': 'Afar'}

# %%
language_json[1]['code']
# Out:
# 'aa'

# %%
len(language_json)
# Out:
# 184

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
rw_sentences = [
    'Umwana Murizi ntakurwa urutozi',
    'Serubyibyinyurimbyisi yambyonyoye',
    'Sogokuru aryoha aboze',
    "Amategeko y' abanebwe"
]

# %%
df['english'] = sentences[:4]

# %%
df
# Out:
#                                   rw                        kinyarwanda  \
# 0     Umwana Murizi ntakurwa urutozi     Umwana Murizi ntakurwa urutozi
# 1  Serubyibyinyurimbyisi yambyonyoye  Serubyibyinyurimbyisi yambyonyoye
# 2              Sogokuru aryoha aboze              Sogokuru aryoha aboze
# 3              Amategeko y' abanebwe              Amategeko y' abanebwe
#
#                              english
# 0                    Jesus is alive!
# 1  Hands on projects is our priority
# 2              I don't have anything
# 3                 It is a rainly day

# %%
for language in language_json[80:100]:
  code = language['code']
  try:
    df[code] = model.translate(df['english'], source_lang= 'en', target_lang=code)
  except:
    pass
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1364: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 512 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,
# Downloading:   0%|          | 0.00/802k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/606k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.01M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/models/marian/tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Downloading:   0%|          | 0.00/276M [00:00<?, ?B/s]
# ...

# %%
df['english']
# Out:
# 0                      Jesus is alive!
# 1    Hands on projects is our priority
# 2                I don't have anything
# 3                   It is a rainly day
# Name: english, dtype: object
